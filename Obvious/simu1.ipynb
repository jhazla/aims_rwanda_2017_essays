# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx
import random
#import SimPy.Simulation as Sim
# %matplotlib inline
import igraph as ig

# %%
G =nx.navigable_small_world_graph(20, p=1, q=0, r=2, dim=2, seed=None)
#nx.draw_spectral(G, node_size =20)

# %%
Pw = 0.04
for node in G.nodes():
    C = random.random()
    if Pw  > C:
        G.add_edge(node,(random.choice(G.nodes())))
nx.draw_spectral(G, node_size =20)
# Out:
# /usr/lib/python3/dist-packages/matplotlib/collections.py:609: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors_original != 'face':
# /usr/lib/python3/dist-packages/matplotlib/collections.py:549: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %%
status[node]

# %%
status = {}
for node in G.nodes(): status[node] = 'S'
for j in range (10):status[random.choice(G.nodes())] ='I'
# Infecting nodes
prob_I = 0.2
prob_R =0
S = len(G.nodes())-10
E = 0
I = 10
R = 0
s = []
e = []
i = []
r = []
t = 0
newI =0
newR =0
newE = 0
newIList = []
while I > 0:
    for node  in G.nodes():
        if status[node] == 'I':
            if prob_R > random.random():
                newR=+1
                status[node] ='R'
            else:
                for nei in G.neighbors(node):
                    if status[nei] == 'S':
                        if random.random() > prob_I:
                            newE=+1
                            status[node] = 'E'
                    
        
                
                     
                 
        elif status[node] == 'E': 
                if random.uniform(0,14) < 7:
                    newI=+1
                    status[node] = 'I'
            
            
                
            
        
    
    S  -= newI
    E  += newE
    I  += (newI - newR)
    R  += newR
    
    s.append(S)
    i.append(I)
    r.append(R)
    newIList.append(newI)
    
print (s)
print(i)
print(e)
print(r)
